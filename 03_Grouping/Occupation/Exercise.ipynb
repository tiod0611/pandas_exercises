# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = data

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
users = users.set_index('user_id')

# %%
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
(users[users['gender'] == 'M'].groupby('occupation').age.count() / users.occupation.value_counts()).sort_values(ascending=False)
# Out:
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender']).age.agg(['min', 'max'])
# Out:
#                       min  max
# occupation    gender
# administrator F        22   62
#               M        21   70
# artist        F        19   48
#               M        20   45
# doctor        M        28   64
# educator      F        23   51
#               M        25   63
# engineer      F        23   36
#               M        22   70
# entertainment F        24   38
#               M        15   50
# executive     F        39   49
#               M        22   69
# healthcare    F        22   53
#               M        28   62
# homemaker     F        20   50
#               M        23   23
# lawyer        F        28   51
#               M        21   53
# librarian     F        26   59
#               M        23   69
# marketing     F        24   50
#               M        24   55
# none          F        26   55
#               M        11   33
# other         F        18   55
#               M        13   64
# programmer    F        26   38
#               M        20   63
# retired       F        70   70
#               M        51   73
# salesman      F        18   33
#               M        21   66
# scientist     F        26   31
#               M        23   55
# student       F        13   38
#               M         7   42
# technician    F        38   38
#               M        21   55
# writer        F        18   56
#               M        21   60

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
# 직업별 남녀 비율 구하기

# 고민해볼것
users.groupby(['occupation']).gender.count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: gender, dtype: int64

# %%
gender_occup = users.groupby(['occupation', 'gender']).agg({'gender':'count'})
gender_occup
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7
# educator      F           26
#               M           69
# engineer      F            2
#               M           65
# entertainment F            2
#               M           16
# executive     F            3
#               M           29
# healthcare    F           11
#               M            5
# homemaker     F            6
#               M            1
# lawyer        F            2
#               M           10
# librarian     F           29
#               M           22
# marketing     F           10
#               M           16
# none          F            4
#               M            5
# other         F           36
#               M           69
# programmer    F            6
#               M           60
# retired       F            1
#               M           13
# salesman      F            3
#               M            9
# scientist     F            3
#               M           28
# student       F           60
#               M          136
# technician    F            1
#               M           26
# writer        F           19
#               M           26

# %%
occup_count = users.groupby(['occupation']).agg('count')
occup_count
# Out:
#                age  gender  zip_code
# occupation
# administrator   79      79        79
# artist          28      28        28
# doctor           7       7         7
# educator        95      95        95
# engineer        67      67        67
# entertainment   18      18        18
# executive       32      32        32
# healthcare      16      16        16
# homemaker        7       7         7
# lawyer          12      12        12
# librarian       51      51        51
# marketing       26      26        26
# none             9       9         9
# other          105     105       105
# programmer      66      66        66
# retired         14      14        14
# salesman        12      12        12
# scientist       31      31        31
# student        196     196       196
# technician      27      27        27
# writer          45      45        45

# %%
occup_gender = gender_occup.div(occup_count, level="occupation")
occup_gender
# Out:
#                       age    gender  zip_code
# occupation    gender
# administrator F       NaN  0.455696       NaN
#               M       NaN  0.544304       NaN
# artist        F       NaN  0.464286       NaN
#               M       NaN  0.535714       NaN
# doctor        M       NaN  1.000000       NaN
# educator      F       NaN  0.273684       NaN
#               M       NaN  0.726316       NaN
# engineer      F       NaN  0.029851       NaN
#               M       NaN  0.970149       NaN
# entertainment F       NaN  0.111111       NaN
#               M       NaN  0.888889       NaN
# executive     F       NaN  0.093750       NaN
#               M       NaN  0.906250       NaN
# healthcare    F       NaN  0.687500       NaN
#               M       NaN  0.312500       NaN
# homemaker     F       NaN  0.857143       NaN
#               M       NaN  0.142857       NaN
# lawyer        F       NaN  0.166667       NaN
#               M       NaN  0.833333       NaN
# librarian     F       NaN  0.568627       NaN
#               M       NaN  0.431373       NaN
# marketing     F       NaN  0.384615       NaN
#               M       NaN  0.615385       NaN
# none          F       NaN  0.444444       NaN
#               M       NaN  0.555556       NaN
# other         F       NaN  0.342857       NaN
#               M       NaN  0.657143       NaN
# programmer    F       NaN  0.090909       NaN
#               M       NaN  0.909091       NaN
# retired       F       NaN  0.071429       NaN
#               M       NaN  0.928571       NaN
# salesman      F       NaN  0.250000       NaN
#               M       NaN  0.750000       NaN
# scientist     F       NaN  0.096774       NaN
#               M       NaN  0.903226       NaN
# student       F       NaN  0.306122       NaN
#               M       NaN  0.693878       NaN
# technician    F       NaN  0.037037       NaN
#               M       NaN  0.962963       NaN
# writer        F       NaN  0.422222       NaN
#               M       NaN  0.577778       NaN

# %%
occup_gender.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# programmer     F         0.090909
#                M         0.909091
# retired        F         0.071429
#                M         0.928571
# salesman       F         0.250000
#                M         0.750000
# scientist      F         0.096774
#                M         0.903226
# student        F         0.306122
#                M         0.693878
# technician     F         0.037037
#                M         0.962963
# writer         F         0.422222
#                M         0.577778
# Name: gender, dtype: float64
